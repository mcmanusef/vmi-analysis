# %%
from vmi_analysis.processing import pipelines

input_file = r".\sample data\tpx_0_000000.tpx3"
pipeline = pipelines.TPXFileConverter(input_file, output_path=r".\sample data\tpx_0_000000.h5")
pipeline.set_profile(True)

pipelines.run_pipeline(pipeline)
# Out:
# Initializing pipeline
# reader initialized correctly: 1
# converter initialized correctly: 1
# save initialized correctly: 1
# Starting pipeline
# reader running: 1
# converter running: 1
# save running: 1
# reader status: {'initialized': True, 'running': True, 'holding': True, 'stopped': False}
# 	chunk (Open) queue size: 0 (internal: 0)
# converter status: {'initialized': True, 'running': True, 'holding': False, 'stopped': False}
# 	pixel (Open) queue size: 0 (internal: 0)
# 	tdc (Open) queue size: 0 (internal: 0)
# save status: {'initialized': True, 'running': True, 'holding': False, 'stopped': False}
#
#
# reader status: {'initialized': True, 'running': True, 'holding': True, 'stopped': False}
# 	chunk (Open) queue size: 25391 (internal: 25391)
# converter status: {'initialized': True, 'running': True, 'holding': False, 'stopped': False}
# 	pixel (Open) queue size: 0 (internal: 0)
# 	tdc (Open) queue size: 0 (internal: 0)
# ...
